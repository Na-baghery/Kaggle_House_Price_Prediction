# %%
#House_price_regression_kaggle

# %%
import numpy as np
import pandas as pd
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt 
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor

# %%
#import dataset
train = pd.read_csv('train (1)_house_price.csv')
test = pd.read_csv('test (2)_house_price.csv')

# %%
train = pd.DataFrame(train)
test = pd.DataFrame(test)

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
X = train.drop('SalePrice' , axis=1).copy()

# %%
Y = train['SalePrice'].copy()

# %%
categorical_cols = X.select_dtypes(include=['object']).columns
numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns

# %%
cat_pipeline = Pipeline([
    ('imputer' ,SimpleImputer(missing_values=np.nan , strategy='most_frequent')),
    ('encoder' ,OneHotEncoder(handle_unknown='ignore'))
])

# %%
num_pipeline = Pipeline([
    ('imputer' ,SimpleImputer(missing_values=np.nan ,strategy='mean'))
])

# %%
ct = ColumnTransformer([
    ('cat' , cat_pipeline ,categorical_cols),
    ('num' ,num_pipeline ,numerical_cols)
])

# %%
x_processed = ct.fit_transform(X)

# %%
x_processed
# Out:
# <1460x288 sparse matrix of type '<class 'numpy.float64'>'
# 	with 99436 stored elements in Compressed Sparse Row format>

# %%
x_processed_df = pd.DataFrame(x_processed.toarray())
print(x_processed_df.shape)
# Out:
# (1460, 288)

# %%
#Random forest model

# %%
Random_forest_model =RandomForestRegressor(
    n_estimators=500,
    random_state=42,
    n_jobs=1
)

# %%
Random_forest_model.fit(x_processed , Y)
# Out:
# RandomForestRegressor(n_estimators=500, n_jobs=1, random_state=42)

# %%
Random_forest_preds = Random_forest_model.predict(x_processed)

# %%
Random_forest_mae = mean_absolute_error(Y ,Random_forest_preds)

# %%
print(Random_forest_mae)
# Out:
# 6354.740020547945

# %%
#Linear Regression model

# %%
Linear_regression_model =LinearRegression()

# %%
Linear_regression_model.fit(x_processed , Y)
# Out:
# LinearRegression()

# %%
Linear_regression_preds = Linear_regression_model.predict(x_processed)

# %%
Linear_regression_mae = mean_absolute_error(Y ,Linear_regression_preds)

# %%
print(Linear_regression_mae)
# Out:
# 15882.708071958596

# %%
#ُSVR model

# %%
svr_model =SVR(kernel='rbf')

# %%
svr_model.fit(x_processed,Y)
# Out:
# SVR()

# %%
svr_preds = svr_model.predict(x_processed)

# %%
svr_mae = mean_absolute_error(Y,svr_preds)

# %%
print(svr_mae)
# Out:
# 55517.9124210392

# %%
#GradientBoosting model

# %%
GradientBoosting_model = GradientBoostingRegressor()

# %%
GradientBoosting_model.fit(x_processed,Y)
# Out:
# GradientBoostingRegressor()

# %%
GradientBoosting_pred = GradientBoosting_model.predict(x_processed)

# %%
GradientBoosting_mae = mean_absolute_error(Y,GradientBoosting_pred)

# %%
print(GradientBoosting_mae)
# Out:
# 10721.989949427065

# %%
#KNeighborsRegression model

# %%
KNeighborsRegressor_model = KNeighborsRegressor()

# %%
KNeighborsRegressor_model.fit(x_processed,Y)
# Out:
# KNeighborsRegressor()

# %%
KNeighborsRegressor_pred = KNeighborsRegressor_model.predict(x_processed)

# %%
KNeighborsRegressor_mae = mean_absolute_error(Y ,KNeighborsRegressor_pred )

# %%
print(KNeighborsRegressor_mae)
# Out:
# 24002.47438356164

# %%
test_proc = ct.transform(test)

# %%
preds_test = Random_forest_model.predict(test_proc)

# %%
print(preds_test)
# Out:
# [129252.852 154472.114 180563.566 182163.4   199192.114 184420.042 165369.482 176399.462 183162.85  119658.004 194698.128  94919.442  96414.6   155002.308 144161.636 387660.894 254070.472 301637.404
#  248113.032 452328.612 309162.988 209671.862 177014.254 178078.008 172480.856 199926.888 330649.428 238440.324 213993.41  198313.53  191511.886  98702.762 175254.028 298963.56  297413.368 228956.446
#  193551.716 153683.804 153629.814 150839.76  174517.024 167424.988 301258.26  228862.624 216804.97  186668.624 217248.186 201449.27  165957.84  150179.892 151115.474 171423.268 152333.016 162227.202
#  176342.22  160403.576 150003.062 128753.088 223028.55  136247.6   143787.8   161916.198 114650.948 121797.632 124042.912 128574.138 101530.312 126170.71  141421.384 166554.88  129391.802 107760.86
# ...

# %%
np.set_printoptions(suppress=True, linewidth=200, threshold=np.inf)
print(preds_test)
# Out:
# [129252.852 154472.114 180563.566 182163.4   199192.114 184420.042 165369.482 176399.462 183162.85  119658.004 194698.128  94919.442  96414.6   155002.308 144161.636 387660.894 254070.472 301637.404
#  248113.032 452328.612 309162.988 209671.862 177014.254 178078.008 172480.856 199926.888 330649.428 238440.324 213993.41  198313.53  191511.886  98702.762 175254.028 298963.56  297413.368 228956.446
#  193551.716 153683.804 153629.814 150839.76  174517.024 167424.988 301258.26  228862.624 216804.97  186668.624 217248.186 201449.27  165957.84  150179.892 151115.474 171423.268 152333.016 162227.202
#  176342.22  160403.576 150003.062 128753.088 223028.55  136247.6   143787.8   161916.198 114650.948 121797.632 124042.912 128574.138 101530.312 126170.71  141421.384 166554.88  129391.802 107760.86
# ...

# %%
submission = pd.DataFrame({
    "Id": range(1461, 2920),
    "SalePrice": preds_test
})

submission.to_csv("submission.csv", index=False)
print("CSV file saved!")
# Out:
# CSV file saved!
